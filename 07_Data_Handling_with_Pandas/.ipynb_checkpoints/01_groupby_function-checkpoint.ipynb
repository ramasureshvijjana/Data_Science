# %% [markdown]
# # Groupby Function

# %%
import pandas as pd

data = pd.read_csv('../00_data/deaths-temperature-gasparrini.csv')
data.head()
# Out:
#      country Code  Year  Extreme cold  Moderate cold  Moderate heat  \
# 0  Australia  AUS  2015          0.67           5.82           0.14
# 1     Brazil  BRA  2015          0.49           2.34           0.48
# 2     Canada  CAN  2015          0.25           4.21           0.27
# 3      China  CHN  2015          1.06           9.31           0.24
# 4      Italy  ITA  2015          0.85           8.51           0.94
#
#    Extreme heat
# 0          0.32
# 1          0.22
# 2          0.26
# 3          0.40
# 4          0.67

# %%
data = data.iloc[:,1:]
data.head()
# Out:
#   Code  Year  Extreme cold  Moderate cold  Moderate heat  Extreme heat
# 0  AUS  2015          0.67           5.82           0.14          0.32
# 1  BRA  2015          0.49           2.34           0.48          0.22
# 2  CAN  2015          0.25           4.21           0.27          0.26
# 3  CHN  2015          1.06           9.31           0.24          0.40
# 4  ITA  2015          0.85           8.51           0.94          0.67

# %%
print(data.groupby('Code'))

# %%
print(data.groupby('Code').sum())
# Out:
#       Year  Extreme cold  Moderate cold  Moderate heat  Extreme heat
# Code
# AUS   2015          0.67           5.82           0.14          0.32
# BRA   2015          0.49           2.34           0.48          0.22
# CAN   4030          0.50           8.42           0.54          0.52
# CHN   4030          2.12          18.62           0.48          0.80
# ESP   6045          2.13          14.25           1.62          1.56
# GBR   2015          0.86           7.62           0.07          0.22
# ITA   4030          1.70          17.02           1.88          1.34
# JPN   6045          2.31          27.12           0.39          0.54
# KOR   6045          1.05          19.74           0.30          0.63
# SWE   6045          0.81          10.32           0.09          0.45
# THA   4030          0.88           4.34           0.94          0.56
# TWN   6045          2.13           9.57           1.80          0.75
# ...

# %%
print(data.groupby('Code').sum()['Moderate cold'])
# Out:
# Code
# AUS     5.82
# BRA     2.34
# CAN     8.42
# CHN    18.62
# ESP    14.25
# GBR     7.62
# ITA    17.02
# JPN    27.12
# KOR    19.74
# SWE    10.32
# THA     4.34
# TWN     9.57
# USA     5.15
# Name: Moderate cold, dtype: float64

# %%
groupd_data = data.groupby('Code').sum()
data2 = groupd_data[groupd_data['Moderate cold'] > 5]
data2
# Out:
#       Year  Extreme cold  Moderate cold  Moderate heat  Extreme heat
# Code
# AUS   2015          0.67           5.82           0.14          0.32
# CAN   4030          0.50           8.42           0.54          0.52
# CHN   4030          2.12          18.62           0.48          0.80
# ESP   6045          2.13          14.25           1.62          1.56
# GBR   2015          0.86           7.62           0.07          0.22
# ITA   4030          1.70          17.02           1.88          1.34
# JPN   6045          2.31          27.12           0.39          0.54
# KOR   6045          1.05          19.74           0.30          0.63
# SWE   6045          0.81          10.32           0.09          0.45
# TWN   6045          2.13           9.57           1.80          0.75
# USA   2015          0.45           5.15           0.14          0.21

# %%
print(data.groupby('Code').filter(lambda x: x['Moderate heat'].sum() > .9)['Moderate heat'])
# Out:
# 4     0.94
# 7     0.54
# 9     0.60
# 10    0.47
# 15    0.54
# 17    0.60
# 20    0.94
# 23    0.54
# 25    0.60
# 26    0.47
# Name: Moderate heat, dtype: float64

# %%
print(data.groupby('Code').count())
# Out:
#       Year  Extreme cold  Moderate cold  Moderate heat  Extreme heat
# Code
# AUS      1             1              1              1             1
# BRA      1             1              1              1             1
# CAN      2             2              2              2             2
# CHN      2             2              2              2             2
# ESP      3             3              3              3             3
# GBR      1             1              1              1             1
# ITA      2             2              2              2             2
# JPN      3             3              3              3             3
# KOR      3             3              3              3             3
# SWE      3             3              3              3             3
# THA      2             2              2              2             2
# TWN      3             3              3              3             3
# ...
