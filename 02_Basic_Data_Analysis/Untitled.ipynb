# %% [markdown]
# # Basic Data Analysis

# %% [markdown]
# ## 1. Display Data

# %%
# Loading data
import pandas as pd

df = pd.read_csv('E:/DATA_SCIENCE/DS/DataScience/data/nyc_flights.csv')

# %% [markdown]
# ### 1.1 Display whole data:

# %%
df
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 1      2013      5    7      1657         -3      2104         10      DL
# 2      2013     12    8       859         -1      1238         11      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 4      2013      7   21      1102         -3      1230         -8      9E
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %% [markdown]
# ### 1.2 Display staring rows
# > By default, head argument n = 5, so by default it displays first 5 rows.

# %%
df.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      6   30       940         15      1216         -4      VX  N626VA
# 1  2013      5    7      1657         -3      2104         10      DL  N3760C
# 2  2013     12    8       859         -1      1238         11      DL  N712TW
# 3  2013      5   14      1841         -4      2122        -34      DL  N914DL
# 4  2013      7   21      1102         -3      1230         -8      9E  N823AY
#
#    flight origin dest  air_time  distance  hour  minute
# 0     407    JFK  LAX       313      2475     9      40
# 1     329    JFK  SJU       216      1598    16      57
# 2     422    JFK  LAX       376      2475     8      59
# 3    2391    JFK  TPA       135      1005    18      41
# 4    3652    LGA  ORF        50       296    11       2

# %% [markdown]
# > If we want to display specific number of rows then pass needful number to head().

# %%
df.head(3)
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      6   30       940         15      1216         -4      VX  N626VA
# 1  2013      5    7      1657         -3      2104         10      DL  N3760C
# 2  2013     12    8       859         -1      1238         11      DL  N712TW
#
#    flight origin dest  air_time  distance  hour  minute
# 0     407    JFK  LAX       313      2475     9      40
# 1     329    JFK  SJU       216      1598    16      57
# 2     422    JFK  LAX       376      2475     8      59

# %% [markdown]
# > if we pass -ve values then it will remove specified number of rows from lst and display remaining rows.

# %%
df.head(-32730)
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      6   30       940         15      1216         -4      VX  N626VA
# 1  2013      5    7      1657         -3      2104         10      DL  N3760C
# 2  2013     12    8       859         -1      1238         11      DL  N712TW
# 3  2013      5   14      1841         -4      2122        -34      DL  N914DL
# 4  2013      7   21      1102         -3      1230         -8      9E  N823AY
#
#    flight origin dest  air_time  distance  hour  minute
# 0     407    JFK  LAX       313      2475     9      40
# 1     329    JFK  SJU       216      1598    16      57
# 2     422    JFK  LAX       376      2475     8      59
# 3    2391    JFK  TPA       135      1005    18      41
# 4    3652    LGA  ORF        50       296    11       2

# %% [markdown]
# ### 1.3 Display last rows

# %% [markdown]
# > By default, tail argument n = 5, so by default it displays last 5 rows.

# %%
df.tail()
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# 32730  N8505Q    3611    JFK  PIT        63       340     7      52
# 32731  N6713Y    1429    JFK  LAS       286      2248     8      12
# 32732  N77871    1545    EWR  IAH       180      1400    10      57
# 32733  N258JB    1273    JFK  CHS        93       636     8      44
# 32734  N36272    1053    EWR  CLE        59       404    18      13

# %% [markdown]
# > f we want to display specific number of rows from last then pass needful number to tail().

# %%
df.tail(3)
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# 32732  N77871    1545    EWR  IAH       180      1400    10      57
# 32733  N258JB    1273    JFK  CHS        93       636     8      44
# 32734  N36272    1053    EWR  CLE        59       404    18      13

# %% [markdown]
# > if we pass -ve values then it will remove specified number of rows from starting and display remaining rows.

# %%
df.tail(-32729)
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 32729  2013      1   28       706         36       909         22      EV
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# 32729  N13914    4419    EWR  IND       105       645     7       6
# 32730  N8505Q    3611    JFK  PIT        63       340     7      52
# 32731  N6713Y    1429    JFK  LAS       286      2248     8      12
# 32732  N77871    1545    EWR  IAH       180      1400    10      57
# 32733  N258JB    1273    JFK  CHS        93       636     8      44
# ...

# %% [markdown]
# ## 2. Understanding Data Size

# %% [markdown]
# ### 2.1 Shape:
# > Shape  will provoide the column and rows information.

# %%
df.shape
# Out:
# (32735, 16)

# %%
shape = df.shape
print(f'Rows    : {shape[0]}')
print(f'Columns : {shape[1]}')
# Out:
# Rows    : 32735
# Columns : 16

# %% [markdown]
# ### 2.2 Size:
# > Size will give total number of labels / vaues in data.

# %%
size = df.size
print(f'Size is: {size}')
# Out:
# Size is: 523760

# %%
size = shape[0] * shape[1]
print(f'Size is: {size}')
# Out:
# Size is: 523760

# %% [markdown]
# ### 2.3 ndim:
# > ndim will give data dimention.

# %%
dimention = df.ndim
print(f'Data dimention is : {dimention}')
# Out:
# Data dimention is : 2

# %% [markdown]
# ### 2.4 info():
# > Info() function will give total information of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32735 entries, 0 to 32734
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       32735 non-null  int64
#  1   month      32735 non-null  int64
#  2   day        32735 non-null  int64
#  3   dep_time   32735 non-null  int64
#  4   dep_delay  32735 non-null  int64
#  5   arr_time   32735 non-null  int64
#  6   arr_delay  32735 non-null  int64
#  7   carrier    32735 non-null  object
#  8   tailnum    32735 non-null  object
#  9   flight     32735 non-null  int64
#  10  origin     32735 non-null  object
#  11  dest       32735 non-null  object
#  12  air_time   32735 non-null  int64
#  13  distance   32735 non-null  int64
#  14  hour       32735 non-null  int64
#  15  minute     32735 non-null  int64
# dtypes: int64(12), object(4)
# memory usage: 4.0+ MB

# %% [markdown]
# ## Handling rows and indexes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32735, step=1)

# %%
clm_index_df = df.set_index('dep_time')
print(f'After set a column as index : ')
clm_index_df.head()
# Out:
# After set a column as index :
#           year  month  day  dep_delay  arr_time  arr_delay carrier tailnum  \
# dep_time
# 940       2013      6   30         15      1216         -4      VX  N626VA
# 1657      2013      5    7         -3      2104         10      DL  N3760C
# 859       2013     12    8         -1      1238         11      DL  N712TW
# 1841      2013      5   14         -4      2122        -34      DL  N914DL
# 1102      2013      7   21         -3      1230         -8      9E  N823AY
#
#           flight origin dest  air_time  distance  hour  minute
# dep_time
# 940          407    JFK  LAX       313      2475     9      40
# 1657         329    JFK  SJU       216      1598    16      57
# 859          422    JFK  LAX       376      2475     8      59
# 1841        2391    JFK  TPA       135      1005    18      41
# 1102        3652    LGA  ORF        50       296    11       2
