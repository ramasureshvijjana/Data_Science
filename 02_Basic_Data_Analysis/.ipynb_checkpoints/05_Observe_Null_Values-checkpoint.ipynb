# %% [markdown]
# ## Observe Null Values

# %%
import pandas as pd

data = pd.read_csv('E:/DATA_SCIENCE/DS/DataScience/data/nyc_flights.csv')
display(data)
# Out:
#        year  month   day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   NaN       940         15    1216.0         -4      VX
# 1      2013      5   7.0      1657         -3    2104.0         10      DL
# 2      2013     12   8.0       859         -1    1238.0         11      DL
# 3      2013      5  14.0      1841         -4       NaN        -34      DL
# 4      2013      7  21.0      1102         -3    1230.0         -8      9E
# ...     ...    ...   ...       ...        ...       ...        ...     ...
# 32730  2013     10   8.0       752         -8     921.0        -28      9E
# 32731  2013      7   7.0       812         -3    1043.0          8      DL
# 32732  2013      9   3.0      1057         -1    1319.0        -19      UA
# 32733  2013     10  15.0       844         56    1045.0         60      B6
# 32734  2013      3  28.0      1813         -3    1942.0        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %% [markdown]
# ### 1. isna() / isnull() Function

# %%
data.isna()
# Out:
#         year  month    day  dep_time  dep_delay  arr_time  arr_delay  carrier  \
# 0      False  False   True     False      False     False      False    False
# 1      False  False  False     False      False     False      False    False
# 2      False  False  False     False      False     False      False    False
# 3      False  False  False     False      False      True      False    False
# 4      False  False  False     False      False     False      False    False
# ...      ...    ...    ...       ...        ...       ...        ...      ...
# 32730  False  False  False     False      False     False      False    False
# 32731  False  False  False     False      False     False      False    False
# 32732  False  False  False     False      False     False      False    False
# 32733  False  False  False     False      False     False      False    False
# 32734  False  False  False     False      False     False      False    False
#
# ...

# %% [markdown]
# ### 2. notna() / notnull() Function

# %%
data.notna()
# Out:
#        year  month    day  dep_time  dep_delay  arr_time  arr_delay  carrier  \
# 0      True   True  False      True       True      True       True     True
# 1      True   True   True      True       True      True       True     True
# 2      True   True   True      True       True      True       True     True
# 3      True   True   True      True       True     False       True     True
# 4      True   True   True      True       True      True       True     True
# ...     ...    ...    ...       ...        ...       ...        ...      ...
# 32730  True   True   True      True       True      True       True     True
# 32731  True   True   True      True       True      True       True     True
# 32732  True   True   True      True       True      True       True     True
# 32733  True   True   True      True       True      True       True     True
# 32734  True   True   True      True       True      True       True     True
#
# ...

# %% [markdown]
# ### 3. sum() with isna() / notna()

# %%
data.isna().sum()
# Out:
# year         0
# month        0
# day          2
# dep_time     0
# dep_delay    0
# arr_time     1
# arr_delay    0
# carrier      0
# tailnum      0
# flight       3
# origin       0
# dest         1
# air_time     0
# distance     0
# hour         0
# minute       0
# dtype: int64
