# %% [markdown]
# ## Loading Excel Data
# > 1. Excel files takes more time then csv files to load thye data.

# %%
import pandas as pd

data = pd.read_excel('../00_data/excel_formate_data.xlsx')
display(data)
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 1      2013      5    7      1657         -3      2104         10      DL
# 2      2013     12    8       859         -1      1238         11      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 4      2013      7   21      1102         -3      1230         -8      9E
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %% [markdown]
# ### 1. Using All Perameters

# %%
data = pd.read_excel('../00_data/excel_formate_data.xlsx',
                    sheet_name= 'Sheet2',
                    usecols=['NAME', 'AGE', 'SAL'],
                    names=['NAME', 'AGE', 'SAL'],
                    header = 1)
display(data)
# Out:
#      NAME  AGE      SAL
# 0    Rama   28  2000000
# 1  Suresh   27   900000
# 2      Vj   26   750000

# %%
data = pd.read_excel('../00_data/excel_formate_data.xlsx',
                    sheet_name= 'Sheet2',
                    usecols=['NAME', 'AGE', 'SAL'],
                    names=['NAME', 'AGE', 'SAL'],
                    header = 1,
                    index)
display(data)
