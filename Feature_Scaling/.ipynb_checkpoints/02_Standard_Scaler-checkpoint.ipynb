# %% [markdown]
# # Scandard Scaler

# %% [markdown]
# ### 1. Data Loadind

# %%
import pandas as pd

data = pd.read_csv('E:/DS/DataScience/Feature_Scaling/Data/cereal.csv')
display(data.head())

data.drop(0, inplace = True)
data.reset_index(inplace = True)
data.drop('index', axis = 1, inplace = True)
display(data.head())
# Out:
#                         name          mfr         type calories protein  fat  \
# 0                     String  Categorical  Categorical      Int     Int  Int
# 1                  100% Bran            N            C       70       4    1
# 2          100% Natural Bran            Q            C      120       3    5
# 3                   All-Bran            K            C       70       4    1
# 4  All-Bran with Extra Fiber            K            C       50       4    0
#
#   sodium  fiber  carbo sugars potass vitamins shelf weight   cups     rating
# 0    Int  Float  Float    Int    Int      Int   Int  Float  Float      Float
# 1    130     10      5      6    280       25     3      1   0.33  68.402973
# 2     15      2      8      8    135        0     3      1      1  33.983679
# 3    260      9      7      5    320       25     3      1   0.33  59.425505
# 4    140     14      8      0    330       25     3      1    0.5  93.704912
# ...

# %% [markdown]
# ### 2. Select Data

# %% [markdown]
# ### 3. Change Data Type

# %%
print(data.calories.dtype)
# Changing data type
data.calories.astype(int)
print(data.calories.dtype)
# Out:
# object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-c6de96376292> in <module>
#       1 print(data.calories.dtype)
#       2 # Changing data type
# ----> 3 data.calories.astype(int)
#       4 print(data.calories.dtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# ...

# %%
data.dropna(inplace=True)
data = data.astype({'calories':int})
print(data.calories.dtype)
# Out:
# int32

# %% [markdown]
# ### 4. Scaling

# %%
from sklearn.preprocessing import StandardScaler

std_sclr = StandardScaler()

data['calories'] = std_sclr.fit_transform(data.loc[:, ['calories']])

display(data)
# Out:
#                          name mfr type  calories protein fat sodium fiber  \
# 0                   100% Bran   N    C -1.940286       4   1    130    10
# 1           100% Natural Bran   Q    C  0.789394       3   5     15     2
# 2                    All-Bran   K    C -1.940286       4   1    260     9
# 3   All-Bran with Extra Fiber   K    C -3.032158       4   0    140    14
# 4              Almond Delight   R    C  0.243458       2   2    200     1
# ..                        ...  ..  ...       ...     ...  ..    ...   ...
# 72                    Triples   G    C  0.243458       2   1    250     0
# 73                       Trix   G    C  0.243458       1   1    140     0
# 74                 Wheat Chex   R    C -0.302478       3   1    230     3
# 75                   Wheaties   G    C -0.302478       3   1    200     3
# 76        Wheaties Honey Gold   G    C  0.243458       2   1    200     1
#
#    carbo sugars potass vitamins shelf weight  cups     rating
# ...

# %%
data['calories'].mean()
# Out:
# -4.470898126193198e-16
