# %% [markdown]
# ## Duplicate Values

# %%
import pandas as pd

data = pd.read_csv('E:/DATA_SCIENCE/DS/DataScience/data/nyc_flights.csv')
display(data)
# Out:
#        year  month   day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   NaN       940         15    1216.0         -4      VX
# 1      2013      6   NaN       940         15    1216.0         -4      VX
# 2      2013      5   7.0      1657         -3    2104.0         10      DL
# 3      2013     12   8.0       859         -1    1238.0         11      DL
# 4      2013      5  14.0      1841         -4       NaN        -34      DL
# ...     ...    ...   ...       ...        ...       ...        ...     ...
# 32731  2013     10   8.0       752         -8     921.0        -28      9E
# 32732  2013      7   7.0       812         -3    1043.0          8      DL
# 32733  2013      9   3.0      1057         -1    1319.0        -19      UA
# 32734  2013     10  15.0       844         56    1045.0         60      B6
# 32735  2013      3  28.0      1813         -3    1942.0        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %% [markdown]
# ### 1. duplicated() function to identify the duplicate values

# %%
data.duplicated(keep='last')
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32731    False
# 32732    False
# 32733    False
# 32734    False
# 32735    False
# Length: 32736, dtype: bool

# %%
data.duplicated(subset=['year', 'month'], keep='last')
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 32731     True
# 32732    False
# 32733    False
# 32734    False
# 32735    False
# Length: 32736, dtype: bool
