# %% [markdown]
# ## Handling Rows And Indexes

# %% [markdown]
# > Indexes of data is one of the important topics in the data handling.
# > Here will learn about how to see the index numbers and how to set a particular column as index.

# %%
import pandas as pd

data = pd.read_csv('E:/DATA_SCIENCE/DS/DataScience/data/nyc_flights.csv')
display(data)
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 1      2013      5    7      1657         -3      2104         10      DL
# 2      2013     12    8       859         -1      1238         11      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 4      2013      7   21      1102         -3      1230         -8      9E
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %% [markdown]
# ### 1. index perameter
# > Returns list of index numbers

# %%
print(data.index)

print(type(data.index))
# Out:
# RangeIndex(start=0, stop=32735, step=1)
# <class 'pandas.core.indexes.range.RangeIndex'>

# %% [markdown]
# ### 2. set_index() function
# > To set a specific column value as index numbers.

# %%
data.set_index("day", inplace=True)
display(data)
# Out:
#      year  month  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# day
# 30   2013      6       940         15      1216         -4      VX  N626VA
# 7    2013      5      1657         -3      2104         10      DL  N3760C
# 8    2013     12       859         -1      1238         11      DL  N712TW
# 14   2013      5      1841         -4      2122        -34      DL  N914DL
# 21   2013      7      1102         -3      1230         -8      9E  N823AY
# ..    ...    ...       ...        ...       ...        ...     ...     ...
# 8    2013     10       752         -8       921        -28      9E  N8505Q
# 7    2013      7       812         -3      1043          8      DL  N6713Y
# 3    2013      9      1057         -1      1319        -19      UA  N77871
# 15   2013     10       844         56      1045         60      B6  N258JB
# 28   2013      3      1813         -3      1942        -23      UA  N36272
#
#      flight origin dest  air_time  distance  hour  minute
# ...

# %%
data.set_index(["dep_time", "dep_delay"], inplace=True)
display(data)
# Out:
#                     year  month  arr_time  arr_delay carrier tailnum  flight  \
# dep_time dep_delay
# 940       15        2013      6      1216         -4      VX  N626VA     407
# 1657     -3         2013      5      2104         10      DL  N3760C     329
# 859      -1         2013     12      1238         11      DL  N712TW     422
# 1841     -4         2013      5      2122        -34      DL  N914DL    2391
# 1102     -3         2013      7      1230         -8      9E  N823AY    3652
# ...                  ...    ...       ...        ...     ...     ...     ...
# 752      -8         2013     10       921        -28      9E  N8505Q    3611
# 812      -3         2013      7      1043          8      DL  N6713Y    1429
# 1057     -1         2013      9      1319        -19      UA  N77871    1545
# 844       56        2013     10      1045         60      B6  N258JB    1273
# 1813     -3         2013      3      1942        -23      UA  N36272    1053
#
# ...

# %% [markdown]
# ### 4. drop() function
# > Drop some specific rows based on index numbers.

# %%
import pandas as pd

data = pd.read_csv('E:/DATA_SCIENCE/DS/DataScience/data/nyc_flights.csv')

data.drop(1, inplace=True)
display(data)
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 2      2013     12    8       859         -1      1238         11      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 4      2013      7   21      1102         -3      1230         -8      9E
# 5      2013      1    1      1817         -3      2008          3      AA
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
data.drop([2,3,4,6], inplace=True)
display(data)
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 5      2013      1    1      1817         -3      2008          3      AA
# 7      2013      8   13      1920         85      2032         71      B6
# 8      2013      9   26       725        -10      1027         -8      AA
# 9      2013      4   30      1323         62      1549         60      EV
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
print(data.index)
# Out:
# Int64Index([    0,     5,     7,     8,     9,    10,    11,    12,    13,
#                14,
#             ...
#             32725, 32726, 32727, 32728, 32729, 32730, 32731, 32732, 32733,
#             32734],
#            dtype='int64', length=32730)
